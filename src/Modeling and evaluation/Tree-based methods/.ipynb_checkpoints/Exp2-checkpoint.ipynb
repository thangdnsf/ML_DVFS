# %%
from expetator.tools import read_experiment, show_heatmap, add_objectives
from expetator.tools import prune_vectors, mojitos_to_vectors, show_pct_distribution
from expetator.monitors import mojitos
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import roc_auc_score
from xgboost import XGBClassifier
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# %%
basename = ['../../'+ path for path in 
            ['datasets/large/0_allpct_grisou-15.nancy.grid5000.fr_1589459642.zip',
           'datasets/large/0_allpct_grisou-1.nancy.grid5000.fr_1589456512.zip',
           'datasets/large/0_allpct_grisou-1.nancy.grid5000.fr_1589492304.zip',
           'datasets/large/0_allpct_grisou-1.nancy.grid5000.fr_1589554681.zip',
           'datasets/large/0_allpct_grisou-1.nancy.grid5000.fr_1589565839.zip']]

# %%
knowledge, mojitos_data = read_experiment(basename, only_complete=True)
vectors = mojitos_to_vectors(mojitos_data, knowledge)

# %%
metric = 'energy'
# 'energy' : energy in joules
# 'duration' : duration in second
# 'etp' : energy time product 

_ = add_objectives(knowledge, objective_name='target', group_label='expe', metric=metric, ratio=1.05, stay_is_zero=False)
_ = add_objectives(knowledge, objective_name='targetZ', group_label='expe', metric=metric, ratio=1.05, stay_is_zero=True)

# %%
vectors
# Out:
#       cache_references     dummy    cache_dtlb  ref_cpu_cycles    cache_node  \
# 0         9.072569e+06  0.000000  2.493961e+05    7.317361e+08  1.892884e+04
# 1         8.474391e+06  0.000000  2.390860e+05    6.272922e+08  1.657539e+04
# 2         7.670776e+06  0.000000  2.973723e+05    5.759597e+08  1.719086e+04
# 3         9.405229e+06  0.000000  2.681103e+05    7.012072e+08  1.875787e+04
# 4         9.489615e+06  0.000000  2.781767e+05    6.837131e+08  1.812383e+04
# ...                ...       ...           ...             ...           ...
# 2231      2.375313e+09  0.026316  5.941870e+08    2.402793e+03  3.117484e+09
# 2232      2.237861e+09  0.037543  5.750929e+08    3.165375e+03  3.119611e+09
# 2233      2.334617e+09  0.071429  5.618092e+08    2.803918e+03  3.120830e+09
# 2234      2.472471e+09  0.022059  6.478483e+08    2.807059e+03  3.123171e+09
# 2235      2.441793e+09  0.030189  6.519103e+08    3.102072e+03  3.122146e+09
#
#          cache_bpu  cache_op_prefetch    task_clock  cache_op_read  \
# 0     8.637292e+07       48323.266260  2.988947e+09  277574.660569
# 1     8.158556e+07       40005.828571  2.989117e+09  288941.544898
# 2     7.660756e+07       45808.652344  2.992094e+09  315687.101562
# 3     9.178032e+07       48142.602062  2.994263e+09  282786.426804
# 4     9.165810e+07       45599.527607  2.994758e+09  308959.797546
# ...            ...                ...           ...            ...
# 2231  4.213588e+05           0.000000  0.000000e+00       0.000000
# 2232  3.982701e+05           0.000000  0.000000e+00       0.000000
# 2233  4.728646e+05           0.000000  0.000000e+00       0.000000
# 2234  5.061467e+05           0.000000  0.000000e+00       0.000000
# 2235  6.035524e+05           0.000000  0.000000e+00       0.000000
#
#         bpf_output  ...  nice    system        idle  iowait  irq  softirq  \
# 0     0.000000e+00  ...   0.0  1.231707  156.445122     0.0  0.0      0.0
# 1     0.000000e+00  ...   0.0  1.202041  156.585714     0.0  0.0      0.0
# 2     0.000000e+00  ...   0.0  1.177734  161.728516     0.0  0.0      0.0
# 3     0.000000e+00  ...   0.0  1.152577  156.587629     0.0  0.0      0.0
# 4     0.000000e+00  ...   0.0  1.137014  156.768916     0.0  0.0      0.0
# ...            ...  ...   ...       ...         ...     ...  ...      ...
# 2231  8.060154e+08  ...   0.0  0.345395  157.924342     0.0  0.0      0.0
# 2232  6.893087e+08  ...   0.0  0.331058  157.843003     0.0  0.0      0.0
# 2233  7.819510e+08  ...   0.0  0.335714  158.067857     0.0  0.0      0.0
# 2234  7.192367e+08  ...   0.0  0.349265  158.198529     0.0  0.0      0.0
# 2235  6.768855e+08  ...   0.0  0.369811  157.992453     0.0  0.0      0.0
#
#       steal  guest  guest_nice     freq
# 0       0.0    0.0         0.0  1200000
# 1       0.0    0.0         0.0  1300000
# 2       0.0    0.0         0.0  1400000
# 3       0.0    0.0         0.0  1500000
# 4       0.0    0.0         0.0  1600000
# ...     ...    ...         ...      ...
# 2231    0.0    0.0         0.0  2000000
# 2232    0.0    0.0         0.0  2100000
# 2233    0.0    0.0         0.0  2200000
# 2234    0.0    0.0         0.0  2300000
# 2235    0.0    0.0         0.0  2400000
#
# [2236 rows x 47 columns]

# %%
knowledge
# Out:
#                          hostname             fullname  nproc   duration  \
# 0     grisou-15.nancy.grid5000.fr               mem-16     64  59.237493
# 1     grisou-15.nancy.grid5000.fr               mem-16     64  58.788879
# 2     grisou-15.nancy.grid5000.fr               mem-16     64  61.097058
# 3     grisou-15.nancy.grid5000.fr               mem-16     64  56.435018
# 4     grisou-15.nancy.grid5000.fr               mem-16     64  58.267301
# ...                           ...                  ...    ...        ...
# 2231   grisou-1.nancy.grid5000.fr  mpigeneric-0-16-0-0     64  36.052643
# 2232   grisou-1.nancy.grid5000.fr  mpigeneric-0-16-0-0     64  34.461414
# 2233   grisou-1.nancy.grid5000.fr  mpigeneric-0-16-0-0     64  33.139848
# 2234   grisou-1.nancy.grid5000.fr  mpigeneric-0-16-0-0     64  31.996871
# 2235   grisou-1.nancy.grid5000.fr  mpigeneric-0-16-0-0     64  30.995938
#
#        startTime     endTime     fmin     fmax  \
# 0     1589459701  1589459763  1200000  1200000
# 1     1589459783  1589459844  1200000  1300000
# 2     1589459857  1589459921  1200000  1400000
# 3     1589459933  1589459994  1200000  1500000
# 4     1589460006  1589460067  1200000  1600000
# ...          ...         ...      ...      ...
# 2231  1589649853  1589649891  1200000  2000000
# 2232  1589649904  1589649940  1200000  2100000
# 2233  1589649952  1589649987  1200000  2200000
# 2234  1589650000  1589650034  1200000  2300000
# 2235  1589650046  1589650079  1200000  2400000
#
#                                                hostlist  \
# 0     grisou-15.nancy.grid5000.fr;grisou-16.nancy.gr...
# 1     grisou-15.nancy.grid5000.fr;grisou-16.nancy.gr...
# 2     grisou-15.nancy.grid5000.fr;grisou-16.nancy.gr...
# 3     grisou-15.nancy.grid5000.fr;grisou-16.nancy.gr...
# 4     grisou-15.nancy.grid5000.fr;grisou-16.nancy.gr...
# ...                                                 ...
# 2231  grisou-1.nancy.grid5000.fr;grisou-2.nancy.grid...
# 2232  grisou-1.nancy.grid5000.fr;grisou-2.nancy.grid...
# 2233  grisou-1.nancy.grid5000.fr;grisou-2.nancy.grid...
# 2234  grisou-1.nancy.grid5000.fr;grisou-2.nancy.grid...
# 2235  grisou-1.nancy.grid5000.fr;grisou-2.nancy.grid...
#
#                                              basename  expe       power  \
# 0     0_allpct_grisou-15.nancy.grid5000.fr_1589459642     0  212.260000
# 1     0_allpct_grisou-15.nancy.grid5000.fr_1589459642     0  215.122449
# 2     0_allpct_grisou-15.nancy.grid5000.fr_1589459642     0  213.245283
# 3     0_allpct_grisou-15.nancy.grid5000.fr_1589459642     0  221.056604
# 4     0_allpct_grisou-15.nancy.grid5000.fr_1589459642     0  223.500000
# ...                                               ...   ...         ...
# 2231   0_allpct_grisou-1.nancy.grid5000.fr_1589565839   171  237.724138
# 2232   0_allpct_grisou-1.nancy.grid5000.fr_1589565839   171  242.035714
# 2233   0_allpct_grisou-1.nancy.grid5000.fr_1589565839   171  247.230769
# 2234   0_allpct_grisou-1.nancy.grid5000.fr_1589565839   171  252.307692
# 2235   0_allpct_grisou-1.nancy.grid5000.fr_1589565839   171  258.840000
#
#             energy            etp   target  targetZ
# 0     12573.750264  744837.443258  1200000        0
# 1     12646.807623  743491.643099  1300000        0
# 2     13028.659425  796012.760541  1400000        0
# 3     12475.333413  704045.665718  1500000        0
# 4     13022.741773  758800.014762  1600000        0
# ...            ...            ...      ...      ...
# 2231   8570.583477  308992.186409  2400000  2400000
# 2232   8340.892953  287438.965176  2100000        0
# 2233   8193.190113  271521.074988  2200000        0
# 2234   8073.056683  258312.553264  2300000        0
# 2235   8022.988592  248680.056970  2400000        0
#
# [2236 rows x 16 columns]

# %% [markdown]
# ## Data Cleaning & Pre-processing

# %%
X_train, X_test, y_train, y_test = train_test_split(vectors, knowledge.target, test_size=0.2, random_state=42)

# %%
sc = StandardScaler()
df_train = sc.fit_transform(X_train)
df_test = sc.transform(X_test)
df_train_sc = pd.DataFrame(df_train,columns = vectors.columns)
df_test_sc = pd.DataFrame(df_test,columns = vectors.columns)

# %%
df_train_sc
# Out:
#       cache_references     dummy  cache_dtlb  ref_cpu_cycles  cache_node  \
# 0             0.665388 -0.371955    0.460400       -0.384652    0.971390
# 1             1.185951 -0.371955    0.607143       -0.385023    0.987199
# 2            -0.340767  2.069130   -0.647283       -0.382732   -1.045695
# 3             0.825578 -0.371955    0.849633       -0.384825    0.945781
# 4             1.883320 -0.371955    1.857834       -0.384625    0.960763
# ...                ...       ...         ...             ...         ...
# 1783          0.508219 -0.371955    0.726376       -0.384549    0.947818
# 1784          0.046259 -0.371955    0.205570       -0.384445    0.958327
# 1785          2.977638 -0.371955    2.914678       -0.385033    0.979200
# 1786          0.749168 -0.371955    0.890363       -0.384366    0.970054
# 1787         -0.534162  0.586923   -0.691814       -0.363713   -1.045695
#
#       cache_bpu  cache_op_prefetch  task_clock  cache_op_read  bpf_output  \
# 0     -0.461836          -0.518118   -0.429507      -0.482731    0.891563
# 1     -0.499210          -0.518118   -0.429507      -0.482731    0.811009
# 2     -0.482553           0.514670   -0.428007       2.103966   -1.086205
# 3     -0.430325          -0.518118   -0.429507      -0.482731    0.735405
# 4     -0.492558          -0.518118   -0.429507      -0.482731    0.739776
# ...         ...                ...         ...            ...         ...
# 1783  -0.487659          -0.518118   -0.429507      -0.482731    0.819121
# 1784  -0.090455          -0.518118   -0.429507      -0.482731    0.999351
# 1785  -0.491829          -0.518118   -0.429507      -0.482731    0.583821
# 1786  -0.444765          -0.518118   -0.429507      -0.482731    0.781566
# 1787  -0.487238           0.206447   -0.421142       1.708873   -1.086205
#
#       ...  nice    system      idle    iowait  irq   softirq  steal  guest  \
# 0     ...   0.0  1.055862 -0.007041 -0.084261  0.0  3.753880    0.0    0.0
# 1     ...   0.0 -0.882598  0.005834 -0.084261  0.0 -0.617983    0.0    0.0
# 2     ...   0.0  0.272288 -0.006481 -0.084261  0.0 -0.313153    0.0    0.0
# 3     ...   0.0 -0.503633 -0.018449 -0.084261  0.0  0.657484    0.0    0.0
# 4     ...   0.0 -0.098813 -0.007580 -0.084261  0.0 -0.273447    0.0    0.0
# ...   ...   ...       ...       ...       ...  ...       ...    ...    ...
# 1783  ...   0.0 -0.319475 -0.017777 -0.084261  0.0  0.074596    0.0    0.0
# 1784  ...   0.0 -0.098132 -0.017772 -0.084261  0.0  0.547651    0.0    0.0
# 1785  ...   0.0 -0.881095 -0.009266 -0.084261  0.0 -0.617983    0.0    0.0
# 1786  ...   0.0 -0.222573 -0.014165 -0.084261  0.0  0.941159    0.0    0.0
# 1787  ...   0.0  0.046889 -0.014314 -0.084261  0.0  0.325344    0.0    0.0
#
#       guest_nice      freq
# 0            0.0  0.533647
# 1            0.0  1.336362
# 2            0.0 -0.001496
# 3            0.0 -1.339355
# 4            0.0 -0.804212
# ...          ...       ...
# 1783         0.0 -1.606927
# 1784         0.0 -0.804212
# 1785         0.0  1.603934
# 1786         0.0  0.266075
# 1787         0.0 -1.071783
#
# [1788 rows x 47 columns]

# %%
columns = ['cache_references', 'dummy', 'cache_dtlb', 'ref_cpu_cycles',
       'cache_node', 'cache_bpu', 'cache_op_prefetch', 'task_clock',
       'cache_op_read', 'bpf_output', 'cache_ll', 'cpu_clock', 'bus_cycles',
       'cache_misses', 'page_faults_min', 'page_faults_maj',
       'cache_result_access', 'alignment_faults', 'cache_l1d',
       'cpu_migrations', 'emulation_faults', 'context_switches',
       'instructions', 'cache_itlb', 'page_faults', 'cpu_cycles',
       'branch_instructions', 'branch_misses', 'rxp', 'rxb', 'txp', 'txb',
       'package-00', 'dram0', 'package-11', 'dram1', 'user', 'nice', 'system',
       'idle', 'iowait', 'irq', 'softirq', 'steal', 'guest', 'guest_nice',
       'freq']

# %%
clf = xgb.XGBClassifier(objective="multi:softprob",n_estimators=5500,learning_rate = 0.3, max_depth=10,gamma=0.0,min_child_weight=1,subsample = 0.7,colsample_bytree = 0.7, random_state=42 )
clf.fit(df_train_sc, y_train, eval_metric=['merror'], eval_set=[(df_train_sc, y_train),(df_test_sc,y_test)], verbose=True, early_stopping_rounds=50)
# Out:
# [0]	validation_0-merror:0.19351	validation_1-merror:0.31027
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 50 rounds.
# [1]	validation_0-merror:0.11633	validation_1-merror:0.27009
# [2]	validation_0-merror:0.07606	validation_1-merror:0.25446
# [3]	validation_0-merror:0.05872	validation_1-merror:0.25223
# [4]	validation_0-merror:0.04306	validation_1-merror:0.24107
# [5]	validation_0-merror:0.03747	validation_1-merror:0.22321
# [6]	validation_0-merror:0.03244	validation_1-merror:0.21205
# [7]	validation_0-merror:0.02573	validation_1-merror:0.20982
# [8]	validation_0-merror:0.01957	validation_1-merror:0.20312
# [9]	validation_0-merror:0.01790	validation_1-merror:0.20089
# [10]	validation_0-merror:0.01622	validation_1-merror:0.20312
# [11]	validation_0-merror:0.01175	validation_1-merror:0.19420
# [12]	validation_0-merror:0.00839	validation_1-merror:0.19196
# [13]	validation_0-merror:0.00503	validation_1-merror:0.18080
# [14]	validation_0-merror:0.00447	validation_1-merror:0.18527
# [15]	validation_0-merror:0.00336	validation_1-merror:0.18080
# [16]	validation_0-merror:0.00280	validation_1-merror:0.17634
# [17]	validation_0-merror:0.00112	validation_1-merror:0.17634
# [18]	validation_0-merror:0.00056	validation_1-merror:0.17188
# [19]	validation_0-merror:0.00056	validation_1-merror:0.17188
# [20]	validation_0-merror:0.00056	validation_1-merror:0.17188
# [21]	validation_0-merror:0.00000	validation_1-merror:0.17188
# [22]	validation_0-merror:0.00000	validation_1-merror:0.17634
# [23]	validation_0-merror:0.00000	validation_1-merror:0.17411
# [24]	validation_0-merror:0.00000	validation_1-merror:0.17188
# [25]	validation_0-merror:0.00000	validation_1-merror:0.16964
# [26]	validation_0-merror:0.00000	validation_1-merror:0.17188
# [27]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [28]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [29]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [30]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [31]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [32]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [33]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [34]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [35]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [36]	validation_0-merror:0.00000	validation_1-merror:0.16964
# [37]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [38]	validation_0-merror:0.00000	validation_1-merror:0.17188
# [39]	validation_0-merror:0.00000	validation_1-merror:0.16964
# [40]	validation_0-merror:0.00000	validation_1-merror:0.17411
# [41]	validation_0-merror:0.00000	validation_1-merror:0.17188
# [42]	validation_0-merror:0.00000	validation_1-merror:0.17188
# [43]	validation_0-merror:0.00000	validation_1-merror:0.17411
# [44]	validation_0-merror:0.00000	validation_1-merror:0.17188
# [45]	validation_0-merror:0.00000	validation_1-merror:0.17188
# [46]	validation_0-merror:0.00000	validation_1-merror:0.17188
# [47]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [48]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [49]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [50]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [51]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [52]	validation_0-merror:0.00000	validation_1-merror:0.16964
# [53]	validation_0-merror:0.00000	validation_1-merror:0.16964
# [54]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [55]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [56]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [57]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [58]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [59]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [60]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [61]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [62]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [63]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [64]	validation_0-merror:0.00000	validation_1-merror:0.16071
# [65]	validation_0-merror:0.00000	validation_1-merror:0.16071
# [66]	validation_0-merror:0.00000	validation_1-merror:0.16071
# [67]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [68]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [69]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [70]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [71]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [72]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [73]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [74]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [75]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [76]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [77]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [78]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [79]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [80]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [81]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [82]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [83]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [84]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [85]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [86]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [87]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [88]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [89]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [90]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [91]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [92]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [93]	validation_0-merror:0.00000	validation_1-merror:0.16071
# [94]	validation_0-merror:0.00000	validation_1-merror:0.16071
# [95]	validation_0-merror:0.00000	validation_1-merror:0.16071
# [96]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [97]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [98]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [99]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [100]	validation_0-merror:0.00000	validation_1-merror:0.16295
# [101]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [102]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [103]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [104]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [105]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [106]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [107]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [108]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [109]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [110]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [111]	validation_0-merror:0.00000	validation_1-merror:0.16518
# [112]	validation_0-merror:0.00000	validation_1-merror:0.16741
# [113]	validation_0-merror:0.00000	validation_1-merror:0.16071
# [114]	validation_0-merror:0.00000	validation_1-merror:0.16518
# Stopping. Best iteration:
# [64]	validation_0-merror:0.00000	validation_1-merror:0.16071
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.7, gamma=0.0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.3, max_delta_step=0, max_depth=10,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=5500, n_jobs=0, num_parallel_tree=1,
#               objective='multi:softprob', random_state=42, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=0.7,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
feature_important = clf.get_booster().get_score(importance_type='weight')

# %%
keys = list(feature_important.keys())
values = list(feature_important.values())
data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=True)
data.to_csv('importance_feature_cf.csv')

# %%
data.index
# Out:
# Index(['context_switches', 'branch_instructions', 'page_faults',
#        'page_faults_min', 'dummy', 'cpu_clock', 'cache_op_read', 'task_clock',
#        'cache_op_prefetch', 'txb', 'cache_l1d', 'emulation_faults',
#        'cache_node', 'cpu_cycles', 'softirq', 'instructions',
#        'cache_references', 'bus_cycles', 'cache_misses', 'alignment_faults',
#        'cache_ll', 'branch_misses', 'cache_dtlb', 'txp', 'cache_result_access',
#        'cache_bpu', 'bpf_output', 'cpu_migrations', 'page_faults_maj',
#        'cache_itlb', 'ref_cpu_cycles', 'package-11', 'rxb', 'dram1', 'dram0',
#        'package-00', 'idle', 'user', 'system', 'rxp', 'freq'],
#       dtype='object')

# %%
objects = data.index
y_pos = np.arange(len(objects))
performance = data['score']

plt.figure(figsize=(10,14))
plt.barh(y_pos, performance, align='center')
plt.yticks(y_pos, objects)
plt.xlabel('score')
plt.title('Top feature importances')
plt.show()

# %%
preds = clf.predict(df_test_sc)

# %%
accuracy = accuracy_score(y_test, preds)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 83.93%

# %%
labels = list(set(knowledge.target))
labels.sort()

# %%
cfm = confusion_matrix(y_test, preds, labels = labels)
plt.figure(figsize=(18,15))
ax = sns.heatmap(cfm, annot=True, cmap="YlGnBu")
ax.set_xticklabels(labels)
ax.set_yticklabels(labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
